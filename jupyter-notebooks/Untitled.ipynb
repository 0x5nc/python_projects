# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'jupyter-notebooks.ipynb',
#  'supermarkets.json',
#  'Untitled.ipynb']

# %%
import json
file = json.load(open("supermarkets.json","r"))

# %%
file
# Out:
# [{'ID': 1,
#   'Address': '3666 21st St',
#   'City': 'San Francisco',
#   'State': 'CA 94114',
#   'Country': 'USA',
#   'Name': 'Madeira',
#   'Employees': 8},
#  {'ID': 2,
#   'Address': '735 Dolores St',
#   'City': 'San Francisco',
#   'State': 'CA 94119',
#   'Country': 'USA',
#   'Name': 'Bready Shop',
#   'Employees': 15},
#  {'ID': 3,
#   'Address': '332 Hill St',
#   'City': 'San Francisco',
#   'State': 'California 94114',
#   'Country': 'USA',
#   'Name': 'Super River',
#   'Employees': 25},
#  {'ID': 4,
#   'Address': '3995 23rd St',
#   'City': 'San Francisco',
#   'State': 'CA 94114',
#   'Country': 'USA',
#   'Name': "Ben's Shop",
#   'Employees': 10},
#  {'ID': 5,
#   'Address': '1056 Sanchez St',
#   'City': 'San Francisco',
#   'State': 'California',
#   'Country': 'USA',
#   'Name': 'Sanchez',
#   'Employees': 12},
#  {'ID': 6,
#   'Address': '551 Alvarado St',
#   'City': 'San Francisco',
#   'State': 'CA 94114',
#   'Country': 'USA',
#   'Name': 'Richvalley',
# ...

# %%
import pandas as pd
df1 = pd.read_csv("paris_airbnb.csv")
df1
# Out:
#      host_response_rate  host_acceptance_rate  host_listings_count  latitude  \
# 0                  100%                   NaN                  1.0  48.83349
# 1                  100%                   NaN                  1.0  48.85100
# 2                  100%                   NaN                  2.0  48.85758
# 3                  100%                   NaN                  1.0  48.86528
# 4                   67%                   NaN                  3.0  48.85899
# ...                 ...                   ...                  ...       ...
# 7995               100%                   NaN                  2.0  48.87901
# 7996                NaN                   NaN                  1.0  48.88903
# 7997               100%                   NaN                  1.0  48.85313
# 7998                NaN                   NaN                  1.0  48.88066
# 7999               100%                   NaN                  2.0  48.85760
#
# ...

# %%
df1.shape
# Out:
# (8000, 19)

# %%
df2 = pd.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df3 = pd.read_csv("https://pythonhow.com/supermarkets.csv")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df4= df3.set_index("ID")
df4
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df4.set_index?

# %%
df4.loc[2:5,"City":"Name"]
# Out:
#              City             State Country         Name
# ID
# 2   San Francisco          CA 94119     USA  Bready Shop
# 3   San Francisco  California 94114     USA  Super River
# 4   San Francisco          CA 94114     USA   Ben's Shop
# 5   San Francisco        California     USA      Sanchez

# %%
df4.loc[2,"Name"]
# Out:
# 'Bready Shop'

# %%
df4.loc[:,"Name"]
# Out:
# ID
# 1        Madeira
# 2    Bready Shop
# 3    Super River
# 4     Ben's Shop
# 5        Sanchez
# 6     Richvalley
# Name: Name, dtype: object

# %%
df4.iloc[2:4,-3:]
# Out:
#    Country         Name  Employees
# ID
# 3      USA  Super River         25
# 4      USA   Ben's Shop         10

# %%
df5 = df4.drop(df4.index[0:3])
df5
# Out:
#             Address           City       State Country        Name  Employees
# ID
# 4      3995 23rd St  San Francisco    CA 94114     USA  Ben's Shop         10
# 5   1056 Sanchez St  San Francisco  California     USA     Sanchez         12
# 6   551 Alvarado St  San Francisco    CA 94114     USA  Richvalley         20

# %%
df6  =df4.drop("City",1)
df6
# Out:
#             Address             State Country         Name  Employees
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df7 = df4.drop(df4.columns[1:3],1)
df7
# Out:
#             Address Country         Name  Employees
# ID
# 1      3666 21st St     USA      Madeira          8
# 2    735 Dolores St     USA  Bready Shop         15
# 3       332 Hill St     USA  Super River         25
# 4      3995 23rd St     USA   Ben's Shop         10
# 5   1056 Sanchez St     USA      Sanchez         12
# 6   551 Alvarado St     USA   Richvalley         20

# %%
df7 = df7.drop(df7.columns[1:3],1)
df7
# Out:
#             Address  Employees
# ID
# 1      3666 21st St          8
# 2    735 Dolores St         15
# 3       332 Hill St         25
# 4      3995 23rd St         10
# 5   1056 Sanchez St         12
# 6   551 Alvarado St         20

# %%
df5 = df5.drop(df5.index[0:3])
df5
# Out:
# Empty DataFrame
# Columns: [Address, City, State, Country, Name, Employees]
# Index: []

# %%
df6.columns
# Out:
# Index(['Address', 'State', 'Country', 'Name', 'Employees'], dtype='object')

# %%
df6.shape
# Out:
# (6, 5)

# %%
df6["Continent"]=df6.shape[0]*["North America"]

# %%
df6
# Out:
#             Address             State Country         Name  Employees  \
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20
#
#         Continent
# ID
# 1   North America
# 2   North America
# 3   North America
# 4   North America
# 5   North America
# 6   North America

# %%
df6["Continent"] = df6["Continent"] + ", " + df6["Country"]

# %%
df6
# Out:
#             Address             State Country         Name  Employees  \
# ID
# 1      3666 21st St          CA 94114     USA      Madeira          8
# 2    735 Dolores St          CA 94119     USA  Bready Shop         15
# 3       332 Hill St  California 94114     USA  Super River         25
# 4      3995 23rd St          CA 94114     USA   Ben's Shop         10
# 5   1056 Sanchez St        California     USA      Sanchez         12
# 6   551 Alvarado St          CA 94114     USA   Richvalley         20
#
#              Continent
# ID
# 1   North America, USA
# 2   North America, USA
# 3   North America, USA
# 4   North America, USA
# 5   North America, USA
# 6   North America, USA

# %%
df8 = df6.T

# %%
df8
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  North America, USA  North America, USA  North America, USA
#
# ID                          4                   5                   6
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# Name               Ben's Shop             Sanchez          Richvalley
# Employees                  10                  12                  20
# ...

# %%
df8["My Address"] = ["My City", "My State", "My Country", "My name", "10", "My Continent"]

# %%
df8
# Out:
# ID                          1                   2                   3  \
# Address          3666 21st St      735 Dolores St         332 Hill St
# State                CA 94114            CA 94119    California 94114
# Country                   USA                 USA                 USA
# Name                  Madeira         Bready Shop         Super River
# Employees                   8                  15                  25
# Continent  North America, USA  North America, USA  North America, USA
#
# ID                          4                   5                   6  \
# Address          3995 23rd St     1056 Sanchez St     551 Alvarado St
# State                CA 94114          California            CA 94114
# Country                   USA                 USA                 USA
# Name               Ben's Shop             Sanchez          Richvalley
# Employees                  10                  12                  20
# ...

# %%
df7 = df8.T

# %%
df7
# Out:
#                     Address             State     Country         Name  \
# ID
# 1              3666 21st St          CA 94114         USA      Madeira
# 2            735 Dolores St          CA 94119         USA  Bready Shop
# 3               332 Hill St  California 94114         USA  Super River
# 4              3995 23rd St          CA 94114         USA   Ben's Shop
# 5           1056 Sanchez St        California         USA      Sanchez
# 6           551 Alvarado St          CA 94114         USA   Richvalley
# My Address          My City          My State  My Country      My name
#
#            Employees           Continent
# ID
# 1                  8  North America, USA
# 2                 15  North America, USA
# 3                 25  North America, USA
# 4                 10  North America, USA
# 5                 12  North America, USA
# 6                 20  North America, USA
# My Address        10        My Continent

# %%
df9 = df2

# %%
df9
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df9["Address"] = df9["Address"]+ ", "+ df9["City"]+ ", "+df9["State"]+ ", "+df9["Country"]

# %%
df9
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(user_agent="provider")

# %%
n = nom.geocode(df9.Address[0])

# %%
df9.Address[0]
# Out:
# '3666 21st St, San Francisco, CA 94114, USA'

# %%
df9.Address
# Out:
# 0           3666 21st St, San Francisco, CA 94114, USA
# 1         735 Dolores St, San Francisco, CA 94119, USA
# 2    332 Hill St, San Francisco, California 94114, USA
# 3           3995 23rd St, San Francisco, CA 94114, USA
# 4      1056 Sanchez St, San Francisco, California, USA
# 5        551 Alvarado St, San Francisco, CA 94114, USA
# Name: Address, dtype: object

# %%
type(n)
# Out:
# geopy.location.Location

# %%
print (n)
# Out:
# 3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, San Francisco, California, 94114, United States

# %%
n
# Out:
# Location(3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, San Francisco, California, 94114, United States, (37.75664965, -122.42940540299549, 0.0))

# %%
locations = [nom.geocode([df9["Address"][i]]) for i in range(0,len (df9["Address"]))]

# %%
df9["locations"] = locations

# %%
df9
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                            locations
# ...

# %%
df9.locations[0]
# Out:
# Location(3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, San Francisco, California, 94114, United States, (37.75664965, -122.42940540299549, 0.0))

# %%
df10 = df9

# %%
df10.locations = ""

# %%
df10.locations = df9.Address.apply(nom.geocode)

# %% [markdown]
# This is a new way of applying a method on a whole column in a new one called locations in df10

# %%
df10.locations
# Out:
# 0    (3666, 21st Street, Noe Valley, San Francisco,...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, San Francisco, ...
# 3    (3995, 23rd Street, Noe Valley, San Francisco,...
# 4    (1056;1058;1060;1062, Sanchez Street, Noe Vall...
# 5    (551, Alvarado Street, Noe Valley, San Francis...
# Name: locations, dtype: object

# %%
df9.locations
# Out:
# 0    (3666, 21st Street, Noe Valley, San Francisco,...
# 1    (735, Dolores Street, Liberty Street Historic ...
# 2    (332, Hill Street, Noe Valley, San Francisco, ...
# 3    (3995, 23rd Street, Noe Valley, San Francisco,...
# 4    (1056;1058;1060;1062, Sanchez Street, Noe Vall...
# 5    (551, Alvarado Street, Noe Valley, San Francis...
# Name: locations, dtype: object

# %%
df10.locations[0]
# Out:
# Location(3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, San Francisco, California, 94114, United States, (37.75664965, -122.42940540299549, 0.0))

# %%
df9.locations[0]
# Out:
# Location(3666, 21st Street, Noe Valley, San Francisco, San Francisco City and County, San Francisco, California, 94114, United States, (37.75664965, -122.42940540299549, 0.0))

# %%
df10.latitudes = df10.locations.latitude
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-59c17e0f2d8c> in <module>
# ----> 1 df10.latitudes = df10.locations.latitude
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'latitude'

# %%
df10["Latitudes"] = df10.locations.apply ( lambda x:x.latitude if x != None else None)

# %%
df10
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                            locations  Latitudes
# ...

# %%
df10["Longitudes"] = df10.locations.apply ( lambda x:x.longitude if x != None else None)

# %%
df10
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                            locations  Latitudes  Longitudes
# ...
